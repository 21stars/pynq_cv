# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from IPython import display
import time

# %%
img = cv2.imread("data/FHD_1.jpg")
#convert img colour space from BGR to RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
canvas = plt.gcf()
size = canvas.get_size_inches()
canvas.set_size_inches(size*2)
print("Image size: {}x{} pixels.".format(1920, 1080))
_ = plt.imshow(img_rgb)
# Out:
# Image size: 1920x1080 pixels.

# %%
width = 1920
height = 1080
# create Mats
gray = np.zeros([height, width, 1], np.uint8)
blur = np.zeros([height, width, 1], np.uint8)
sobel_x = np.zeros([height, width, 1], np.int16)
sobel_y = np.zeros([height, width, 1], np.int16)
sobel_g = np.zeros([height, width, 1], np.int8)

# %%
gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray,(3,3),0)

sobel_x = cv2.Sobel(blur, cv2.CV_16S, 1, 0, ksize=3)
sobel_y = cv2.Sobel(blur, cv2.CV_16S, 0, 1, ksize=3)

sobel_x = cv2.convertScaleAbs(sobel_x)
sobel_y = cv2.convertScaleAbs(sobel_y)
sobel_g = cv2.addWeighted(sobel_x, 0.5, sobel_y, 0.5, 0)

sobel_x = cv2.Sobel(blur, cv2.CV_16S, 1, 0, ksize=3)
sobel_y = cv2.Sobel(blur, cv2.CV_16S, 0, 1, ksize=3)

# %%
canvas = plt.gcf()
size = canvas.get_size_inches()
canvas.set_size_inches(size*2)
print("Image size: {}x{} pixels.".format(1920, 1080))
_ = plt.imshow(sobel_g, cmap='gray')
# Out:
# Image size: 1920x1080 pixels.

# %%
cv2.imwrite("sw_sobeled.jpg",sobel_g)
# Out:
# True
